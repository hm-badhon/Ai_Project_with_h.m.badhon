# %%
# !pip install wandb
# Out:
# Collecting wandb
#   Downloading wandb-0.13.9-py2.py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 1.2 MB/s eta 0:00:00m eta 0:00:010:01:01
# Requirement already satisfied: appdirs>=1.4.3 in /home/hmb/anaconda3/envs/bk/lib/python3.10/site-packages (from wandb) (1.4.4)
# Collecting pathtools
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests<3,>=2.0.0 in /home/hmb/anaconda3/envs/bk/lib/python3.10/site-packages (from wandb) (2.28.1)
# Collecting Click!=8.0.0,>=7.0
#   Downloading click-8.1.3-py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.6/96.6 kB 695.6 kB/s eta 0:00:00MB/s eta 0:00:01:01
# Collecting docker-pycreds>=0.4.0
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Collecting setproctitle
#   Downloading setproctitle-1.3.2-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.19.0 in /home/hmb/anaconda3/envs/bk/lib/python3.10/site-packages (from wandb) (3.19.6)
# Requirement already satisfied: psutil>=5.0.0 in /home/hmb/anaconda3/envs/bk/lib/python3.10/site-packages (from wandb) (5.9.3)
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.14.0-py2.py3-none-any.whl (178 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.9/178.9 kB 971.9 kB/s eta 0:00:001.4 MB/s eta 0:00:01
# Collecting GitPython>=1.0.0
#   Downloading GitPython-3.1.30-py3-none-any.whl (184 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.0/184.0 kB 1.0 MB/s eta 0:00:001.5 MB/s eta 0:00:01
# Requirement already satisfied: setuptools in /home/hmb/anaconda3/envs/bk/lib/python3.10/site-packages (from wandb) (63.4.1)
# Collecting PyYAML
#   Downloading PyYAML-6.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (682 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 682.2/682.2 kB 1.2 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: six>=1.4.0 in /home/hmb/anaconda3/envs/bk/lib/python3.10/site-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 569.1 kB/s eta 0:00:0036m0:00:010:00:01
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/hmb/anaconda3/envs/bk/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (1.26.13)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/hmb/anaconda3/envs/bk/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/hmb/anaconda3/envs/bk/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/hmb/anaconda3/envs/bk/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (2022.12.7)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Building wheels for collected packages: pathtools
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8792 sha256=9265d46c14a7785422a814824b7f6af988f291236c48ba4d653884f5e4906891
#   Stored in directory: /home/hmb/.cache/pip/wheels/44/1b/54/249c94316d4e1030e2d0683fba1d8ea06197de866f5a4de738
# Successfully built pathtools
# Installing collected packages: pathtools, smmap, setproctitle, sentry-sdk, PyYAML, docker-pycreds, Click, gitdb, GitPython, wandb
# Successfully installed Click-8.1.3 GitPython-3.1.30 PyYAML-6.0 docker-pycreds-0.4.0 gitdb-4.0.10 pathtools-0.1.2 sentry-sdk-1.14.0 setproctitle-1.3.2 smmap-5.0.0 wandb-0.13.9

# %%
from preprocess import *
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D, LSTM
from keras.utils import to_categorical
import wandb
from wandb.keras import WandbCallback
import matplotlib.pyplot as plt

# %%
wandb.init()
config = wandb.config

config.max_len = 11
config.buckets = 20

# Save data to array file first
save_data_to_array(max_len=config.max_len, n_mfcc=config.buckets)

labels=["bed", "happy", "cat"]
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#  ········
# wandb: Appending key for api.wandb.ai to your netrc file: /home/hmb/.netrc
# Tracking run with wandb version 0.13.9
# Run data is saved locally in <code>/home/hmb/Documents/Github/Ai_Project/cnn-audio/wandb/run-20230207_002141-kubyul7l</code>
# Syncing run <strong><a href="https://wandb.ai/hmbadhon/uncategorized/runs/kubyul7l" target="_blank">soft-wildflower-1</a></strong> to <a href="https://wandb.ai/hmbadhon/uncategorized" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
#  View project at <a href="https://wandb.ai/hmbadhon/uncategorized" target="_blank">https://wandb.ai/hmbadhon/uncategorized</a>
#  View run at <a href="https://wandb.ai/hmbadhon/uncategorized/runs/kubyul7l" target="_blank">https://wandb.ai/hmbadhon/uncategorized/runs/kubyul7l</a>
# Saving vectors of label - 'happy':   0%|               | 0/1742 [00:00<?, ?it/s]/home/hmb/Documents/Github/Ai_Project/cnn-audio/preprocess.py:24: FutureWarning: Pass y=[ 0.00363159  0.00332642  0.00305176 ... -0.00134277 -0.00445557
#  -0.00463867] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mfcc = librosa.feature.mfcc(wave, sr=16000, n_mfcc=n_mfcc)
# Saving vectors of label - 'happy':   0%|       | 1/1742 [00:00<08:21,  3.47it/s]/home/hmb/Documents/Github/Ai_Project/cnn-audio/preprocess.py:24: FutureWarning: Pass y=[ 0.          0.          0.         ...  0.00054932 -0.00216675
#   0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mfcc = librosa.feature.mfcc(wave, sr=16000, n_mfcc=n_mfcc)
# /home/hmb/Documents/Github/Ai_Project/cnn-audio/preprocess.py:24: FutureWarning: Pass y=[6.1035156e-05 6.1035156e-04 6.1035156e-04 ... 5.1879883e-04 4.5776367e-04
#  3.9672852e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mfcc = librosa.feature.mfcc(wave, sr=16000, n_mfcc=n_mfcc)
# /home/hmb/Documents/Github/Ai_Project/cnn-audio/preprocess.py:24: FutureWarning: Pass y=[-0.00445557 -0.00857544 -0.01361084 ...  0.02166748  0.01495361
#   0.0088501 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mfcc = librosa.feature.mfcc(wave, sr=16000, n_mfcc=n_mfcc)
# /home/hmb/Documents/Github/Ai_Project/cnn-audio/preprocess.py:24: FutureWarning: Pass y=[0.01132202 0.01269531 0.01519775 ... 0.0161438  0.01446533 0.01281738] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mfcc = librosa.feature.mfcc(wave, sr=16000, n_mfcc=n_mfcc)
# Saving vectors of label - 'happy':   0%|       | 5/1742 [00:00<01:51, 15.57it/s]/home/hmb/Documents/Github/Ai_Project/cnn-audio/preprocess.py:24: FutureWarning: Pass y=[ 0.0239563   0.02282715  0.04727173 ... -0.03283691 -0.05081177
#  -0.04138184] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mfcc = librosa.feature.mfcc(wave, sr=16000, n_mfcc=n_mfcc)
# /home/hmb/Documents/Github/Ai_Project/cnn-audio/preprocess.py:24: FutureWarning: Pass y=[-0.00302124 -0.00479126 -0.00497437 ... -0.00125122  0.00137329
#   0.00817871] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mfcc = librosa.feature.mfcc(wave, sr=16000, n_mfcc=n_mfcc)
# /home/hmb/Documents/Github/Ai_Project/cnn-audio/preprocess.py:24: FutureWarning: Pass y=[0.00012207 0.00018311 0.00021362 ... 0.0005188  0.0005188  0.00036621] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mfcc = librosa.feature.mfcc(wave, sr=16000, n_mfcc=n_mfcc)
# Saving vectors of label - 'happy':   0%|       | 8/1742 [00:00<02:03, 14.08it/s]/home/hmb/Documents/Github/Ai_Project/cnn-audio/preprocess.py:24: FutureWarning: Pass y=[ 0.01281738  0.01501465  0.01763916 ... -0.01248169 -0.0145874
#  -0.01330566] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mfcc = librosa.feature.mfcc(wave, sr=16000, n_mfcc=n_mfcc)
# /home/hmb/Documents/Github/Ai_Project/cnn-audio/preprocess.py:24: FutureWarning: Pass y=[ 0.          0.00213623 -0.00036621 ...  0.00015259  0.00128174
#   0.00119019] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mfcc = librosa.feature.mfcc(wave, sr=16000, n_mfcc=n_mfcc)
# /home/hmb/Documents/Github/Ai_Project/cnn-audio/preprocess.py:24: FutureWarning: Pass y=[ 0.00033569 -0.00421143 -0.00524902 ...  0.00030518 -0.00042725
#  -0.00131226] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mfcc = librosa.feature.mfcc(wave, sr=16000, n_mfcc=n_mfcc)
# Saving vectors of label - 'happy':
] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mfcc = librosa.feature.mfcc(wave, sr=16000, n_mfcc=n_mfcc)
# /home/hmb/Documents/Github/Ai_Project/cnn-audio/preprocess.py:24: FutureWarning: Pass y=[ 0.          0.          0.         ... -0.00305176 -0.00177002
#  -0.0010376 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mfcc = librosa.feature.mfcc(wave, sr=16000, n_mfcc=n_mfcc)
# /home/hmb/Documents/Github/Ai_Project/cnn-audio/preprocess.py:24: FutureWarning: Pass y=[0.00164795 0.00085449 0.00863647 ... 0.00558472 0.01040649 0.00549316] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mfcc = librosa.feature.mfcc(wave, sr=16000, n_mfcc=n_mfcc)
# Saving vectors of label - 'bed': 100%|█████▉| 1706/1713 [00:15<00:00, 64.29it/s]/home/hmb/Documents/Github/Ai_Project/cnn-audio/preprocess.py:24: FutureWarning: Pass y=[-3.0517578e-05 -6.1035156e-04  9.1552734e-05 ... -1.9226074e-03
#  -1.3122559e-03 -3.6621094e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mfcc = librosa.feature.mfcc(wave, sr=16000, n_mfcc=n_mfcc)
# /home/hmb/Documents/Github/Ai_Project/cnn-audio/preprocess.py:24: FutureWarning: Pass y=[ 0.         -0.00073242 -0.00079346 ...  0.00112915  0.00012207
#   0.00067139] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mfcc = librosa.feature.mfcc(wave, sr=16000, n_mfcc=n_mfcc)
# /home/hmb/Documents/Github/Ai_Project/cnn-audio/preprocess.py:24: FutureWarning: Pass y=[-0.00054932 -0.00024414 -0.00036621 ...  0.00119019  0.00131226
#   0.00100708] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mfcc = librosa.feature.mfcc(wave, sr=16000, n_mfcc=n_mfcc)
# /home/hmb/Documents/Github/Ai_Project/cnn-audio/preprocess.py:24: FutureWarning: Pass y=[-0.00030518 -0.0010376  -0.00039673 ...  0.00357056  0.00320435
#   0.00259399] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mfcc = librosa.feature.mfcc(wave, sr=16000, n_mfcc=n_mfcc)
# /home/hmb/Documents/Github/Ai_Project/cnn-audio/preprocess.py:24: FutureWarning: Pass y=[ 0.00094604  0.00241089 -0.00344849 ... -0.00073242  0.00027466
#  -0.00292969] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mfcc = librosa.feature.mfcc(wave, sr=16000, n_mfcc=n_mfcc)
# /home/hmb/Documents/Github/Ai_Project/cnn-audio/preprocess.py:24: FutureWarning: Pass y=[ 0.00177002  0.00430298  0.00125122 ... -0.00213623 -0.00161743
#  -0.00244141] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mfcc = librosa.feature.mfcc(wave, sr=16000, n_mfcc=n_mfcc)
# /home/hmb/Documents/Github/Ai_Project/cnn-audio/preprocess.py:24: FutureWarning: Pass y=[3.0517578e-05 6.1035156e-05 6.1035156e-05 ... 9.1552734e-05 6.1035156e-05
#  6.1035156e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mfcc = librosa.feature.mfcc(wave, sr=16000, n_mfcc=n_mfcc)
# Saving vectors of label - 'bed': 100%|█████| 1713/1713 [00:16<00:00, 105.23it/s]

# %%
# # Loading train set and test set
X_train, X_test, y_train, y_test = get_train_test()

# %%
# # Feature dimension
channels = 1
config.epochs = 50
config.batch_size = 100

num_classes = 3

X_train = X_train.reshape(X_train.shape[0], config.buckets, config.max_len, channels)
X_test = X_test.reshape(X_test.shape[0], config.buckets, config.max_len, channels)

# %%
plt.imshow(X_train[100, :, :, 0])
print(y_train[100])
# Out:
# 0.0

# %%
y_train_hot = to_categorical(y_train)
y_test_hot = to_categorical(y_test)

# %%
X_train = X_train.reshape(X_train.shape[0], config.buckets, config.max_len)
X_test = X_test.reshape(X_test.shape[0], config.buckets, config.max_len)

model = Sequential()
model.add(Flatten(input_shape=(config.buckets, config.max_len)))
model.add(Dense(num_classes, activation='softmax'))
model.compile(loss="categorical_crossentropy",
                  optimizer="adam",
                  metrics=['accuracy'])
# Out:
# 2023-02-07 00:23:10.915975: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2023-02-07 00:23:10.929320: W tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:265] failed call to cuInit: UNKNOWN ERROR (303)
# 2023-02-07 00:23:10.934622: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (hmbadhon): /proc/driver/nvidia/version does not exist
# 2023-02-07 00:23:10.994979: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
wandb.init()
model.fit(X_train, y_train_hot, epochs=config.epochs, validation_data=(X_test, y_test_hot), callbacks=[WandbCallback(data_type="image", labels=labels)])
# Out:
# Finishing last run (ID:kubyul7l) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
#  View run <strong style="color:#cdcd00">soft-wildflower-1</strong> at: <a href="https://wandb.ai/hmbadhon/uncategorized/runs/kubyul7l" target="_blank">https://wandb.ai/hmbadhon/uncategorized/runs/kubyul7l</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230207_002141-kubyul7l/logs</code>
# Successfully finished last run (ID:kubyul7l). Initializing new run:<br/>
# Tracking run with wandb version 0.13.9
# Run data is saved locally in <code>/home/hmb/Documents/Github/Ai_Project/cnn-audio/wandb/run-20230207_002325-gviozkcl</code>
# Syncing run <strong><a href="https://wandb.ai/hmbadhon/uncategorized/runs/gviozkcl" target="_blank">comfy-sky-2</a></strong> to <a href="https://wandb.ai/hmbadhon/uncategorized" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
#  View project at <a href="https://wandb.ai/hmbadhon/uncategorized" target="_blank">https://wandb.ai/hmbadhon/uncategorized</a>
#  View run at <a href="https://wandb.ai/hmbadhon/uncategorized/runs/gviozkcl" target="_blank">https://wandb.ai/hmbadhon/uncategorized/runs/gviozkcl</a>
# wandb: WARNING The save_model argument by default saves the model in the HDF5 format that cannot save custom objects like subclassed models and custom layers. This behavior will be deprecated in a future release in favor of the SavedModel format. Meanwhile, the HDF5 model is saved as W&B files and the SavedModel as W&B Artifacts.
# wandb: WARNING The data_type argument of wandb.keras.WandbCallback is deprecated and will be removed in a future release. Please use input_type instead.
# wandb: WARNING Setting input_type = data_type.
# Epoch 1/50
#  1/98 [..............................] - ETA: 2:14 - loss: 45.3112 - accuracy: 0.3750WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /home/hmb/Documents/Github/Ai_Project/cnn-audio/wandb/run-20230207_002325-gviozkcl/files/model-best/assets
# INFO:tensorflow:Assets written to: /home/hmb/Documents/Github/Ai_Project/cnn-audio/wandb/run-20230207_002325-gviozkcl/files/model-best/assets
# wandb: Adding directory to artifact (/home/hmb/Documents/Github/Ai_Project/cnn-audio/wandb/run-20230207_002325-gviozkcl/files/model-best)... Done. 0.0s
# wandb: WARNING A graphql request initiated by the public wandb API timed out (timeout=9 sec). Create a new API with an integer timeout larger than 9, e.g., `api = wandb.Api(timeout=19)` to increase the graphql timeout.
# 98/98 [==============================] - 12s 123ms/step - loss: 2.0476 - accuracy: 0.7947 - val_loss: 2.6622 - val_accuracy: 0.7750
# Epoch 13/50
# 2/2 [==============================] - 0s 3ms/step loss: 2.0154 - accuracy: 0.77
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /home/hmb/Documents/Github/Ai_Project/cnn-audio/wandb/run-20230207_002325-gviozkcl/files/model-best/assets
# INFO:tensorflow:Assets written to: /home/hmb/Documents/Github/Ai_Project/cnn-audio/wandb/run-20230207_002325-gviozkcl/files/model-best/assets
# wandb: Adding directory to artifact (/home/hmb/Documents/Github/Ai_Project/cnn-audio/wandb/run-20230207_002325-gviozkcl/files/model-best)... Done. 0.0s
# 98/98 [==============================] - 5s 48ms/step - loss: 1.9938 - accuracy: 0.7808 - val_loss: 2.4887 - val_accuracy: 0.7726
# Epoch 14/50
# 2/2 [==============================] - 0s 3ms/step loss: 1.8242 - accuracy: 0.79
# 98/98 [==============================] - 1s 5ms/step - loss: 1.8140 - accuracy: 0.7905 - val_loss: 2.5545 - val_accuracy: 0.7688
# Epoch 15/50
# 2/2 [==============================] - 0s 2ms/step loss: 1.8744 - accuracy: 0.77
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /home/hmb/Documents/Github/Ai_Project/cnn-audio/wandb/run-20230207_002325-gviozkcl/files/model-best/assets
# INFO:tensorflow:Assets written to: /home/hmb/Documents/Github/Ai_Project/cnn-audio/wandb/run-20230207_002325-gviozkcl/files/model-best/assets
# wandb: Adding directory to artifact (/home/hmb/Documents/Github/Ai_Project/cnn-audio/wandb/run-20230207_002325-gviozkcl/files/model-best)... Done. 0.0s
# 98/98 [==============================] - 1s 14ms/step - loss: 1.7492 - accuracy: 0.7882 - val_loss: 2.2595 - val_accuracy: 0.7770
# Epoch 16/50
# 2/2 [==============================] - 0s 2ms/step loss: 1.6132 - accuracy: 0.80
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /home/hmb/Documents/Github/Ai_Project/cnn-audio/wandb/run-20230207_002325-gviozkcl/files/model-best/assets
# INFO:tensorflow:Assets written to: /home/hmb/Documents/Github/Ai_Project/cnn-audio/wandb/run-20230207_002325-gviozkcl/files/model-best/assets
# wandb: Adding directory to artifact (/home/hmb/Documents/Github/Ai_Project/cnn-audio/wandb/run-20230207_002325-gviozkcl/files/model-best)... Done. 0.0s
# 98/98 [==============================] - 1s 14ms/step - loss: 1.6198 - accuracy: 0.7963 - val_loss: 2.2549 - val_accuracy: 0.7755
# Epoch 17/50
# 2/2 [==============================] - 0s 2ms/step loss: 1.4844 - accuracy: 0.79
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /home/hmb/Documents/Github/Ai_Project/cnn-audio/wandb/run-20230207_002325-gviozkcl/files/model-best/assets
# INFO:tensorflow:Assets written to: /home/hmb/Documents/Github/Ai_Project/cnn-audio/wandb/run-20230207_002325-gviozkcl/files/model-best/assets
# wandb: Adding directory to artifact (/home/hmb/Documents/Github/Ai_Project/cnn-audio/wandb/run-20230207_002325-gviozkcl/files/model-best)... Done. 0.0s
# 98/98 [==============================] - 1s 13ms/step - loss: 1.5034 - accuracy: 0.7950 - val_loss: 2.1176 - val_accuracy: 0.7726
# Epoch 18/50
# 2/2 [==============================] - 0s 2ms/step loss: 1.4467 - accuracy: 0.79
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /home/hmb/Documents/Github/Ai_Project/cnn-audio/wandb/run-20230207_002325-gviozkcl/files/model-best/assets
# INFO:tensorflow:Assets written to: /home/hmb/Documents/Github/Ai_Project/cnn-audio/wandb/run-20230207_002325-gviozkcl/files/model-best/assets
# wandb: Adding directory to artifact (/home/hmb/Documents/Github/Ai_Project/cnn-audio/wandb/run-20230207_002325-gviozkcl/files/model-best)... Done. 0.0s
# 98/98 [==============================] - 2s 18ms/step - loss: 1.4403 - accuracy: 0.7905 - val_loss: 2.1083 - val_accuracy: 0.7722
# Epoch 19/50
# 2/2 [==============================] - 0s 13ms/steploss: 1.4452 - accuracy: 0.79
# 98/98 [==============================] - 0s 4ms/step - loss: 1.4325 - accuracy: 0.7976 - val_loss: 2.3987 - val_accuracy: 0.7365
# Epoch 20/50
# 2/2 [==============================] - 0s 2ms/step loss: 1.3994 - accuracy: 0.79
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /home/hmb/Documents/Github/Ai_Project/cnn-audio/wandb/run-20230207_002325-gviozkcl/files/model-best/assets
# INFO:tensorflow:Assets written to: /home/hmb/Documents/Github/Ai_Project/cnn-audio/wandb/run-20230207_002325-gviozkcl/files/model-best/assets
# wandb: Adding directory to artifact (/home/hmb/Documents/Github/Ai_Project/cnn-audio/wandb/run-20230207_002325-gviozkcl/files/model-best)... Done. 0.1s
# 98/98 [==============================] - 1s 14ms/step - loss: 1.4013 - accuracy: 0.7918 - val_loss: 1.9602 - val_accuracy: 0.7750
# Epoch 21/50
# 2/2 [==============================] - 0s 2ms/step loss: 1.2323 - accuracy: 0.80
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /home/hmb/Documents/Github/Ai_Project/cnn-audio/wandb/run-20230207_002325-gviozkcl/files/model-best/assets
# INFO:tensorflow:Assets written to: /home/hmb/Documents/Github/Ai_Project/cnn-audio/wandb/run-20230207_002325-gviozkcl/files/model-best/assets
# wandb: Adding directory to artifact (/home/hmb/Documents/Github/Ai_Project/cnn-audio/wandb/run-20230207_002325-gviozkcl/files/model-best)... Done. 0.0s
# 98/98 [==============================] - 1s 15ms/step - loss: 1.2623 - accuracy: 0.7976 - val_loss: 1.8690 - val_accuracy: 0.7620
# Epoch 22/50
# 2/2 [==============================] - 0s 5ms/step loss: 1.2274 - accuracy: 0.79
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /home/hmb/Documents/Github/Ai_Project/cnn-audio/wandb/run-20230207_002325-gviozkcl/files/model-best/assets
# INFO:tensorflow:Assets written to: /home/hmb/Documents/Github/Ai_Project/cnn-audio/wandb/run-20230207_002325-gviozkcl/files/model-best/assets
# wandb: Adding directory to artifact (/home/hmb/Documents/Github/Ai_Project/cnn-audio/wandb/run-20230207_002325-gviozkcl/files/model-best)... Done. 0.0s
# 98/98 [==============================] - 1s 14ms/step - loss: 1.2380 - accuracy: 0.7995 - val_loss: 1.7753 - val_accuracy: 0.7697
# Epoch 23/50
# 2/2 [==============================] - 0s 5ms/step loss: 1.0304 - accuracy: 0.81
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /home/hmb/Documents/Github/Ai_Project/cnn-audio/wandb/run-20230207_002325-gviozkcl/files/model-best/assets
# INFO:tensorflow:Assets written to: /home/hmb/Documents/Github/Ai_Project/cnn-audio/wandb/run-20230207_002325-gviozkcl/files/model-best/assets
# wandb: Adding directory to artifact (/home/hmb/Documents/Github/Ai_Project/cnn-audio/wandb/run-20230207_002325-gviozkcl/files/model-best)... Done. 0.0s
# 98/98 [==============================] - 1s 14ms/step - loss: 1.1287 - accuracy: 0.8027 - val_loss: 1.7658 - val_accuracy: 0.7673
# Epoch 24/50
# 2/2 [==============================] - 0s 8ms/step loss: 1.0992 - accuracy: 0.79
# 98/98 [==============================] - 1s 6ms/step - loss: 1.1110 - accuracy: 0.7976 - val_loss: 1.9549 - val_accuracy: 0.7399
# Epoch 25/50
# 2/2 [==============================] - 0s 5ms/step loss: 1.1226 - accuracy: 0.80
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /home/hmb/Documents/Github/Ai_Project/cnn-audio/wandb/run-20230207_002325-gviozkcl/files/model-best/assets
# INFO:tensorflow:Assets written to: /home/hmb/Documents/Github/Ai_Project/cnn-audio/wandb/run-20230207_002325-gviozkcl/files/model-best/assets
# wandb: Adding directory to artifact (/home/hmb/Documents/Github/Ai_Project/cnn-audio/wandb/run-20230207_002325-gviozkcl/files/model-best)... Done. 0.0s
# 98/98 [==============================] - 2s
# 2/2 [==============================] - 0s 3ms/step loss: 0.8697 - accuracy: 0.80
# 98/98 [==============================] - 1s 5ms/step - loss: 0.8570 - accuracy: 0.8049 - val_loss: 1.3761 - val_accuracy: 0.7553
# Epoch 39/50
# 2/2 [==============================] - 0s 10ms/steploss: 0.8600 - accuracy: 0.79
# 98/98 [==============================] - 0s 5ms/step - loss: 0.8703 - accuracy: 0.7905 - val_loss: 1.2370 - val_accuracy: 0.7683
# Epoch 40/50
# 2/2 [==============================] - 0s 3ms/step loss: 0.8383 - accuracy: 0.79
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /home/hmb/Documents/Github/Ai_Project/cnn-audio/wandb/run-20230207_002325-gviozkcl/files/model-best/assets
# INFO:tensorflow:Assets written to: /home/hmb/Documents/Github/Ai_Project/cnn-audio/wandb/run-20230207_002325-gviozkcl/files/model-best/assets
# wandb: Adding directory to artifact (/home/hmb/Documents/Github/Ai_Project/cnn-audio/wandb/run-20230207_002325-gviozkcl/files/model-best)... Done. 0.0s
# 98/98 [==============================] - 2s 26ms/step - loss: 0.8478 - accuracy: 0.7960 - val_loss: 1.2288 - val_accuracy: 0.7596
# Epoch 41/50
# 2/2 [==============================] - 0s 2ms/step loss: 0.8612 - accuracy: 0.79
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /home/hmb/Documents/Github/Ai_Project/cnn-audio/wandb/run-20230207_002325-gviozkcl/files/model-best/assets
# INFO:tensorflow:Assets written to: /home/hmb/Documents/Github/Ai_Project/cnn-audio/wandb/run-20230207_002325-gviozkcl/files/model-best/assets
# wandb: Adding directory to artifact (/home/hmb/Documents/Github/Ai_Project/cnn-audio/wandb/run-20230207_002325-gviozkcl/files/model-best)... Done. 0.0s
# 98/98 [==============================] - 2s 16ms/step - loss: 0.8797 - accuracy: 0.7908 - val_loss: 1.1615 - val_accuracy: 0.7760
# Epoch 42/50
# 2/2 [==============================] - 0s 5ms/step loss: 0.8361 - accuracy: 0.80
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /home/hmb/Documents/Github/Ai_Project/cnn-audio/wandb/run-20230207_002325-gviozkcl/files/model-best/assets
# INFO:tensorflow:Assets written to: /home/hmb/Documents/Github/Ai_Project/cnn-audio/wandb/run-20230207_002325-gviozkcl/files/model-best/assets
# wandb: Adding directory to artifact (/home/hmb/Documents/Github/Ai_Project/cnn-audio/wandb/run-20230207_002325-gviozkcl/files/model-best)... Done. 0.0s
# 98/98 [==============================] - 1s 15ms/step - loss: 0.8254 - accuracy: 0.8027 - val_loss: 1.1166 - val_accuracy: 0.7702
# Epoch 43/50
# 2/2 [==============================] - 0s 4ms/step loss: 0.7914 - accuracy: 0.80
# 98/98 [==============================] - 0s 5ms/step - loss: 0.7886 - accuracy: 0.7985 - val_loss: 1.1637 - val_accuracy: 0.7707
# Epoch 44/50
# 2/2 [==============================] - 0s 3ms/step loss: 0.7646 - accuracy: 0.80
# 98/98 [==============================] - 1s 6ms/step - loss: 0.7748 - accuracy: 0.8037 - val_loss: 1.2483 - val_accuracy: 0.7596
# Epoch 45/50
# 2/2 [==============================] - 0s 3ms/step loss: 0.7401 - accuracy: 0.80
# 98/98 [==============================] - 0s 5ms/step - loss: 0.7604 - accuracy: 0.8027 - val_loss: 1.1526 - val_accuracy: 0.7606
# Epoch 46/50
# 2/2 [==============================] - 0s 3ms/step loss: 0.8429 - accuracy: 0.79
# 98/98 [==============================] - 1s 5ms/step - loss: 0.8421 - accuracy: 0.7915 - val_loss: 1.1981 - val_accuracy: 0.7567
# Epoch 47/50
# 2/2 [==============================] - 0s 3ms/step loss: 0.7763 - accuracy: 0.80
# 98/98 [==============================] - 0s 5ms/step - loss: 0.7990 - accuracy: 0.7982 - val_loss: 1.4574 - val_accuracy: 0.7153
# Epoch 48/50
# 2/2 [==============================] - 0s 3ms/step loss: 0.8371 - accuracy: 0.79
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /home/hmb/Documents/Github/Ai_Project/cnn-audio/wandb/run-20230207_002325-gviozkcl/files/model-best/assets
# INFO:tensorflow:Assets written to: /home/hmb/Documents/Github/Ai_Project/cnn-audio/wandb/run-20230207_002325-gviozkcl/files/model-best/assets
# wandb: Adding directory to artifact (/home/hmb/Documents/Github/Ai_Project/cnn-audio/wandb/run-20230207_002325-gviozkcl/files/model-best)... Done. 0.1s
# 98/98 [==============================] - 2s 21ms/step - loss: 0.8287 - accuracy: 0.7931 - val_loss: 1.0599 - val_accuracy: 0.7832
# Epoch 49/50
# 2/2 [==============================] - 0s 5ms/step loss: 0.7776 - accuracy: 0.80
# 98/98 [==============================] - 0s 5ms/step - loss: 0.7826 - accuracy: 0.8104 - val_loss: 1.1594 - val_accuracy: 0.7678
# Epoch 50/50
# 2/2 [==============================] - 0s 2ms/step loss: 0.6802 - accuracy: 0.81
# 98/98 [==============================] - 0s 4ms/step - loss: 0.7437 - accuracy: 0.8120 - val_loss: 1.1829 - val_accuracy: 0.7592

# %%
# build model
model = Sequential()
model.add(LSTM(22, input_shape=(360,1)))
model.add(Dense(1, activation='sigmoid'))
model.add(Dense(num_classes, activation='softmax'))

# %%
model.compile(loss="categorical_crossentropy",
                  optimizer="adam",
                  metrics=['accuracy'])

# %%
wandb.init()
model.fit(X_train, y_train_hot, epochs=config.epochs, validation_data=(X_test, y_test_hot), callbacks=[WandbCallback(data_type="image", labels=labels)])
# Out:
# Finishing last run (ID:0ccyuxek) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
#  View run <strong style="color:#cdcd00">radiant-haze-3</strong> at: <a href="https://wandb.ai/hmbadhon/uncategorized/runs/0ccyuxek" target="_blank">https://wandb.ai/hmbadhon/uncategorized/runs/0ccyuxek</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230207_002821-0ccyuxek/logs</code>
# Successfully finished last run (ID:0ccyuxek). Initializing new run:<br/>
# Tracking run with wandb version 0.13.9
# Run data is saved locally in <code>/home/hmb/Documents/Github/Ai_Project/cnn-audio/wandb/run-20230207_002937-frnto26o</code>
# Syncing run <strong><a href="https://wandb.ai/hmbadhon/uncategorized/runs/frnto26o" target="_blank">northern-morning-4</a></strong> to <a href="https://wandb.ai/hmbadhon/uncategorized" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
#  View project at <a href="https://wandb.ai/hmbadhon/uncategorized" target="_blank">https://wandb.ai/hmbadhon/uncategorized</a>
#  View run at <a href="https://wandb.ai/hmbadhon/uncategorized/runs/frnto26o" target="_blank">https://wandb.ai/hmbadhon/uncategorized/runs/frnto26o</a>
# Epoch 1/50
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [22], line 2
#       1 wandb.init()
# ----> 2 model.fit(X_train, y_train_hot, epochs=config.epochs, validation_data=(X_test, y_test_hot), callbacks=[WandbCallback(data_type="image", labels=labels)])
#
# File ~/anaconda3/envs/bk/lib/python3.10/site-packages/wandb/integration/keras/keras.py:174, in patch_tf_keras.<locals>.new_v2(*args, **kwargs)
#     172     for cbk in cbks:
#     173         set_wandb_attrs(cbk, val_data)
# --> 174 return old_v2(*args, **kwargs)
#
# File ~/anaconda3/envs/bk/lib/python3.10/site-packages/wandb/integration/keras/keras.py:174, in patch_tf_keras.<locals>.new_v2(*args, **kwargs)
#     172     for cbk in cbks:
#     173         set_wandb_attrs(cbk, val_data)
# --> 174 return old_v2(*args, **kwargs)
#
# File ~/anaconda3/envs/bk/lib/python3.10/site-packages/wandb/integration/keras/keras.py:174, in patch_tf_keras.<locals>.new_v2(*args, **kwargs)
#     172     for cbk in cbks:
#     173         set_wandb_attrs(cbk, val_data)
# --> 174 return old_v2(*args, **kwargs)
#
# File ~/anaconda3/envs/bk/lib/python3.10/site-packages/keras/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File /tmp/__autograph_generated_file8hiw93ir.py:15, in outer_factory.<locals>.inner_factory.<locals>.tf__train_function(iterator)
#      13 try:
#      14     do_return = True
# ---> 15     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16 except:
#      17     do_return = False
#
# ValueError: in user code:
#
#     File "/home/hmb/anaconda3/envs/bk/lib/python3.10/site-packages/keras/engine/training.py", line 1249, in train_function  *
#         return step_function(self, iterator)
#     File "/home/hmb/anaconda3/envs/bk/lib/python3.10/site-packages/keras/engine/training.py", line 1233, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/home/hmb/anaconda3/envs/bk/lib/python3.10/site-packages/keras/engine/training.py", line 1222, in run_step  **
#         outputs = model.train_step(data)
#     File "/home/hmb/anaconda3/envs/bk/lib/python3.10/site-packages/keras/engine/training.py", line 1023, in train_step
#         y_pred = self(x, training=True)
#     File "/home/hmb/anaconda3/envs/bk/lib/python3.10/site-packages/keras/utils/traceback_utils.py", line 70, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "/home/hmb/anaconda3/envs/bk/lib/python3.10/site-packages/keras/engine/input_spec.py", line 295, in assert_input_compatibility
#         raise ValueError(
#
#     ValueError: Input 0 of layer "sequential_3" is incompatible with the layer: expected shape=(None, 360, 1), found shape=(None, 20, 11)
